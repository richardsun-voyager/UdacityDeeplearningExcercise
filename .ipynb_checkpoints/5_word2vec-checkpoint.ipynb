# %% [markdown]
# # Deep Learning
# ## Assignment 5
#
# The goal of this assignment is to train a Word2Vec skip-gram model over Text8 data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary. The data was part of wikipedia, but had been preprocessed, for example, punctuations removed, cases transformed.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
words[:20]
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against',
#  'early',
#  'working',
#  'class',
#  'radicals',
#  'including',
#  'the',
#  'diggers',
#  'of',
#  'the',
#  'english']

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000
#Fetch 50000 words from the original data set
def build_dataset(words):
  #Set the first word as 'UNK'
  count = [['UNK', -1]]
  #Calculate the frequencies of words and select the most frequent 50000 ones
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  #Encode the frequent 50000 words with index in the dictionaray
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  #Encode the rare words with 'UNK'
  #Encode each word with its index
  data = list()
  unk_count = 0
  for word in words:
    #If the word is frequent
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    #Store the index for each word
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
reverse_dictionary[5239]
# Out:
# 'anarchism'

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  '''
  batch_size: the number of batch words
  num_skips: number of words used to make predictions, usually euqal to 2*skip_window
  skip_window: number of left or right words used to predict the target world
  '''
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)#A quene with maximum size of span
  #Get the indices of words within a span
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ] #Record the words selected
    for j in range(num_skips):
      #Randomly choose an unselected word
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      #Find the context of the center word
      batch[i * num_skips + j] = buffer[skip_window]#The center word
      labels[i * num_skips + j, 0] = buffer[target]#The left and right words of center word
    #Shift the index to next word
    buffer.append(data[data_index])#Note, buffer's size remain as span
    data_index = (data_index + 1) % len(data)#The index won't o out of scope
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])
bs = 16
for num_skips, skip_window in [(2, 1), (8, 4)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=bs, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(bs)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term', 'of', 'of', 'abuse', 'abuse', 'first', 'first', 'used', 'used']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'of', 'a', 'term', 'abuse', 'of', 'first', 'abuse', 'used', 'against', 'first']
#
# with num_skips = 8 and skip_window = 4:
#     batch: ['term', 'term', 'term', 'term', 'term', 'term', 'term', 'term', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'of']
#     labels: ['of', 'used', 'originated', 'as', 'a', 'anarchism', 'abuse', 'first', 'abuse', 'term', 'first', 'a', 'as', 'against', 'originated', 'used']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph1 = tf.Graph()

with graph1.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  #Encoding the all the words into vectors, V*M, V is vocabulary size
  #M is encoding size
  #Initalize them in a form of uniform distribution
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  #Assistant vectors for each word
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs, select those vectors for input words.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  # Those words which are not the output can be viewed as negative labels
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 40001

with tf.Session(graph=graph1) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.208791
# Nearest to many: troubadors, halfbakery, lash, ech, cuar, shipwrecked, largo, parables,
# Nearest to by: cheka, derrick, paran, temporal, russo, pins, roosevelt, folk,
# Nearest to or: modernizing, heterotic, formalized, gaff, keefe, rendezvous, employed, strangled,
# Nearest to a: monsignor, swearing, scandals, naturally, shirt, eldest, clocks, exemption,
# Nearest to so: tribunal, dismissing, aces, adamson, integrative, sergius, cartoonists, knoll,
# Nearest to not: reasoning, nostalgia, walrus, circumnavigated, underdogs, endanger, humanists, overflowing,
# Nearest to war: cddb, abdulaziz, exchanges, addington, expense, islas, door, watson,
# Nearest to known: insulinotherapy, classic, robotech, litigation, osiris, dominatrices, hastened, barbiturates,
# Nearest to which: navigation, bitrates, racehorse, despotism, pointless, munch, canaanites, fitzroy,
# Nearest to they: insulator, unter, ogilvie, homosexuals, escalated, controlling, romanian, hermitian,
# Nearest to other: candler, ductile, impairs, yorker, tw, uss, byzantium, usb,
# Nearest to people: cap, mindful, ubiquity, decipherment, gunshot, sheryl, chromatic, csicop,
# Nearest to but: methyl, uploads, einhard, reward, invention, dysprosium, contain, misuse,
# Nearest to be: stormed, famines, enron, karpov, capturing, posted, psychologically, endings,
# Nearest to more: steadman, kusakabe, biostatistics, demonstrably, emmett, parenting, objections, fried,
# Nearest to one: anastasio, gangetic, socony, ula, scrupulously, dolmen, shays, laches,
# Average loss at step 2000: 4.363658
# Average loss at step 4000: 3.862938
# Average loss at step 6000: 3.792157
# Average loss at step 8000: 3.689046
# Average loss at step 10000: 3.615918
# Nearest to many: some, such, cellos, several, hays, concurrent, halfbakery, travel,
# Nearest to by: was, derrick, on, cheka, be, tribune, huey, scanner,
# Nearest to or: and, neoclassical, s, tera, tangerine, than, around, mumia,
# Nearest to a: the, this, his, rgermeister, divisibility, ewald, reveals, redeemed,
# Nearest to so: metabolize, motherboards, lunda, compressible, wark, unfree, fraenkel, tribunal,
# Nearest to not: it, still, reasoning, also, overflowing, you, never, eroding,
# Nearest to war: abdulaziz, manasseh, addington, wilkins, cddb, entries, incompetent, door,
# Nearest to known: dominatrices, percussionist, piccolo, bp, philby, primarily, aluminum, nucleons,
# Nearest to which: that, this, navigation, it, also, isostatic, canaanites, norbert,
# Nearest to they: he, we, it, there, who, reuven, onyx, not,
# Nearest to other: different, anchorage, some, garrett, many, forces, barbera, impairs,
# Nearest to people: reproduction, adolf, artificial, prevenient, lundy, tidal, rossi, csicop,
# Nearest to but: methyl, lesser, fabrication, costa, claimed, openoffice, dealerships, riddled,
# Nearest to be: have, refer, was, rassemblement, is, by, clique, enron,
# Nearest to more: less, kusakabe, biostatistics, geiger, shawn, licence, dobbs, available,
# Nearest to one: two, three, six, seven, four, five, eight, nine,
# Average loss at step 12000: 3.601317
# Average loss at step 14000: 3.572721
# Average loss at step 16000: 3.406290
# Average loss at step 18000: 3.462006
# Average loss at step 20000: 3.536178
# Nearest to many: some, several, these, other, such, all, hays, duplicate,
# Nearest to by: for, be, derrick, from, were, missouri, in, tinted,
# Nearest to or: and, than, briefing, with, mcgraw, while, declares, for,
# Nearest to a: the, this, divisibility, another, phosphate, reveals, no, construed,
# Nearest to so: compressible, if, bicarbonate, metabolize, lunda, anthemius, libertad, animistic,
# Nearest to not: still, it, eroding, they, also, never, reasoning, carlton,
# Nearest to war: manasseh, wilkins, incompetent, door, registers, skilled, relay, meadows,
# Nearest to known: such, primarily, piccolo, used, dominatrices, appendages, treated, bp,
# Nearest to which: that, also, this, who, it, and, foci, there,
# Nearest to they: we, there, he, it, you, not, who, these,
# Nearest to other: many, anchorage, different, some, including, barbera, garrett, nahum,
# Nearest to people: lundy, anachronism, reproduction, csicop, artificial, ombudsman, forward, tidal,
# Nearest to but: however, yet, though, and, while, which, that, was,
# Nearest to be: have, been, were, refer, was, are, by, is,
# Nearest to more: less, visicalc, most, licence, very, throwers, available, indulgence,
# Nearest to one: seven, two, four, eight, six, three, five, nine,
# Average loss at step 22000: 3.503497
# Average loss at step 24000: 3.486063
# Average loss at step 26000: 3.483673
# Average loss at step 28000: 3.479625
# Average loss at step 30000: 3.501303
# Nearest to many: some, several, these, all, other, both, various, their,
# Nearest to by: in, under, were, derrick, tribune, tinted, was, missouri,
# Nearest to or: and, than, probable, while, luminance, tangerine, customization, tulare,
# Nearest to a: the, another, any, ewald, no, sworn, pluralistic, reveals,
# Nearest to so: if, bicarbonate, compressible, extremely, lunda, very, antioch, marvin,
# Nearest to not: still, they, eroding, personae, it, never, you, there,
# Nearest to war: ishaq, incompetent, door, manasseh, dyess, meadows, abdulaziz, relay,
# Nearest to known: used, such, treated, well, primarily, biplanes, dominatrices, appendages,
# Nearest to which: this, that, it, who, what, also, but, there,
# Nearest to they: we, there, he, who, it, you, not, these,
# Nearest to other: different, many, nahum, anchorage, some, various, eplf, several,
# Nearest to people: reproduction, lundy, tidal, soldiers, members, forward, those, men,
# Nearest to but: however, and, though, contain, it, although, while, which,
# Nearest to be: have, been, refer, is, was, bosco, delivers, are,
# Nearest to more: less, very, most, jamison, rather, shawn, dobbs, available,
# Nearest to one: two, seven, three, four, five, six, eight, nine,
# Average loss at step 32000: 3.501040
# Average loss at step 34000: 3.490684
# Average loss at step 36000: 3.453363
# Average loss at step 38000: 3.299846
# Average loss at step 40000: 3.429024
# Nearest to many: some, several, these, both, various, most, those, other,
# Nearest to by: tribune, derrick, be, caution, tucum, essex, when, with,
# Nearest to or: and, than, briefing, a, shimon, tulare, tangerine, mend,
# Nearest to a: the, another, commutators, or, abbreviation, rgermeister, any, divisibility,
# Nearest to so: bicarbonate, if, shawn, longitudes, very, extremely, episcopalian, liked,
# Nearest to not: still, personae, never, it, eroding, they, carlton, you,
# Nearest to war: registers, hint, manasseh, door, publicize, beginning, itu, extinguish,
# Nearest to known: used, such, well, appendages, treated, biplanes, castel, possible,
# Nearest to which: that, this, also, who, what, these, but, there,
# Nearest to they: we, there, he, you, it, these, who, i,
# Nearest to other: different, various, several, many, anchorage, nahum, more, noree,
# Nearest to people: members, generations, men, those, manipulative, tidal, soldiers, forward,
# Nearest to but: however, and, although, though, while, playful, which, before,
# Nearest to be: been, have, refer, is, are, was, were, by,
# Nearest to more: less, most, very, greater, jamison, possessing, highly, indulgence,
# Nearest to one: seven, two, four, six, three, five, eight, nine,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ## Problem
# An alternative to skip-gram is another Word2Vec model called CBOW (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  #Get the indices of words within a span
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      #batch[i * num_skips + j] = buffer[skip_window]
      #labels[i * num_skips + j, 0] = buffer[target]
      batch[i * num_skips + j] = buffer[target]
      labels[i * num_skips + j, 0] = buffer[skip_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'of', 'a']
#     labels: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['a', 'anarchism', 'originated', 'term', 'term', 'as', 'originated', 'of']
#     labels: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph2 = tf.Graph()

with graph2.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  #Encoding the words into vectors
  #Initalize them in a form of uniform distribution
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 40001

with tf.Session(graph=graph2) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.859468
# Nearest to who: spoofed, exam, revoke, kaye, copy, started, bearers, palestinian,
# Nearest to he: forsyth, oeuvre, coon, dyes, southern, nuanced, nanoscale, round,
# Nearest to one: presidents, almost, survivability, ves, borrowed, reinforces, prediction, bithynia,
# Nearest to states: hooker, canoes, defect, amour, shovel, acoustical, mvd, patiently,
# Nearest to united: typically, osteoporosis, bleue, wff, scopes, stephanie, databases, lapse,
# Nearest to has: cromwell, persistence, dmz, marmalade, shield, southwestern, servicio, redefined,
# Nearest to after: nail, jarman, dolphins, paper, leap, agnetha, vengeful, essay,
# Nearest to only: siberia, multilateral, bellarmine, erect, synthesizers, kmt, diocese, preoccupied,
# Nearest to or: aerosols, wanna, variegated, hw, swordsman, conformational, redstone, miggins,
# Nearest to which: cleveland, rdos, omnibus, lies, theatres, jordi, weizenbaum, productive,
# Nearest to on: containment, evaporative, nh, disproved, robotech, continuation, pipe, jefferson,
# Nearest to see: vividly, kyoto, redefine, andechs, rios, westward, raaf, petrie,
# Nearest to with: tina, grammarian, ici, ghost, routine, open, mandriva, epsom,
# Nearest to are: appendages, shifter, faroes, updike, spec, pye, circumnavigation, arana,
# Nearest to be: bosniaks, rod, assailants, zwickau, fredric, footage, azimuth, dispersing,
# Nearest to seven: associate, tub, cloning, ctesiphon, radially, sheen, descriptor, bolstered,
# Average loss at step 2000: 4.359282
# Average loss at step 4000: 3.865840
# Average loss at step 6000: 3.789273
# Average loss at step 8000: 3.684700
# Average loss at step 10000: 3.618295
# Nearest to who: hashshashin, which, uz, concord, it, he, and, aphelion,
# Nearest to he: it, they, she, there, round, cursing, who, abjuration,
# Nearest to one: two, three, seven, six, five, four, motivations, gatherings,
# Nearest to states: acoustical, amour, mathematicians, patiently, propagate, versions, langue, khaganate,
# Nearest to united: bleue, scopes, montserrat, matejko, accrue, alemanni, demeter, memoriam,
# Nearest to has: was, had, is, have, flint, supremacist, saviour, appropriately,
# Nearest to after: with, before, following, guatemalans, electricity, cuckoo, first, abkhaz,
# Nearest to only: sam, periodicals, she, multilateral, aleister, segal, kegan, contemplative,
# Nearest to or: and, corvette, cretans, of, but, musical, harpists, naturalistic,
# Nearest to which: this, also, it, there, that, often, who, he,
# Nearest to on: in, lilly, at, by, factorization, uncle, containment, chaitin,
# Nearest to see: kyoto, capacitive, hutchinson, rohypnol, sutcliffe, vividly, double, chaney,
# Nearest to with: between, after, unsuccessfully, for, regain, in, mandriva, by,
# Nearest to are: were, is, have, hopes, include, was, allegiances, fertilisation,
# Nearest to be: have, is, azimuth, bosniaks, been, was, by, mozart,
# Nearest to seven: six, five, eight, four, nine, three, zero, two,
# Average loss at step 12000: 3.602879
# Average loss at step 14000: 3.571872
# Average loss at step 16000: 3.405641
# Average loss at step 18000: 3.462337
# Average loss at step 20000: 3.542007
# Nearest to who: he, which, concord, never, she, also, often, they,
# Nearest to he: it, she, they, there, who, cursing, cinematographer, never,
# Nearest to one: two, four, three, six, five, seven, eight, nine,
# Nearest to states: acoustical, amour, mirroring, mathematicians, propagate, langue, tex, versions,
# Nearest to united: bleue, demeter, scopes, alemanni, montserrat, matejko, during, accrue,
# Nearest to has: had, have, was, is, appropriately, saviour, opposing, shanghainese,
# Nearest to after: before, with, from, soto, following, guatemalans, for, ruptured,
# Nearest to only: but, periodicals, she, sam, until, aleister, segal, present,
# Nearest to or: and, than, airflow, prostitutes, but, savoie, remorse, playmate,
# Nearest to which: this, that, who, also, there, it, but, nynorsk,
# Nearest to on: in, at, lilly, excavate, disjunctive, near, erroneously, uncle,
# Nearest to see: kyoto, sutcliffe, capacitive, rohypnol, vividly, historians, enjoy, freud,
# Nearest to with: in, between, from, after, into, for, mandriva, through,
# Nearest to are: were, is, have, was, be, allegiances, include, struggling,
# Nearest to be: have, been, refer, is, azimuth, were, was, by,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Average loss at step 22000: 3.503022
# Average loss at step 24000: 3.486832
# Average loss at step 26000: 3.484823
# Average loss at step 28000: 3.481666
# Average loss at step 30000: 3.504409
# Nearest to who: he, she, which, never, they, concord, often, also,
# Nearest to he: she, it, they, who, there, cursing, never, cinematographer,
# Nearest to one: two, four, seven, three, six, eight, five, nine,
# Nearest to states: propagate, acoustical, amour, nations, kingdom, mathematicians, mirroring, jagiellon,
# Nearest to united: alemanni, bleue, demeter, montserrat, rabbani, scopes, matejko, sprite,
# Nearest to has: had, have, was, is, submits, saviour, friesland, shanghainese,
# Nearest to after: before, when, for, following, was, from, during, vasco,
# Nearest to only: periodicals, aleister, not, still, until, simultaneity, segal, zooplankton,
# Nearest to or: and, harpists, but, rhythm, ayya, as, bending, asw,
# Nearest to which: this, that, it, what, also, who, there, hdi,
# Nearest to on: in, lilly, upon, at, near, fogo, through, into,
# Nearest to see: sutcliffe, letterman, inaccurately, desserts, vividly, capacitive, freezing, acquires,
# Nearest to with: between, leonard, from, for, into, proceeds, by, unsuccessfully,
# Nearest to are: were, have, is, include, while, be, these, climbs,
# Nearest to be: been, have, produce, refer, intermittently, are, journeying, were,
# Nearest to seven: eight, nine, four, six, three, five, zero, two,
# Average loss at step 32000: 3.503505
# Average loss at step 34000: 3.493885
# Average loss at step 36000: 3.451165
# Average loss at step 38000: 3.303448
# Average loss at step 40000: 3.424486
# Nearest to who: he, often, she, which, concord, never, always, also,
# Nearest to he: she, it, they, who, there, cursing, i, then,
# Nearest to one: seven, four, two, three, six, eight, five, nine,
# Nearest to states: kingdom, nations, acoustical, amour, reclassified, propagate, teased, cliff,
# Nearest to united: alemanni, foundations, demeter, montserrat, bt, bleue, rabbani, scopes,
# Nearest to has: had, have, was, is, friesland, opposing, shanghainese, having,
# Nearest to after: before, from, during, when, vasco, for, was, sifra,
# Nearest to only: just, periodicals, not, until, still, present, it, zooplankton,
# Nearest to or: and, than, a, prostrate, stardust, the, but, subsidised,
# Nearest to which: that, this, it, also, what, but, who, often,
# Nearest to on: upon, lilly, at, gestapo, through, ladas, in, near,
# Nearest to see: list, sutcliffe, inaccurately, include, can, acquires, freezing, desserts,
# Nearest to with: between, leonard, prefixed, unsuccessfully, by, navigational, daggers, ici,
# Nearest to are: were, is, have, be, include, but, ln, including,
# Nearest to be: been, is, was, have, refer, being, were, are,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# You can see that the numbers are close to each other.
